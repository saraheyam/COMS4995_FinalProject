# %%
import sys
sys.argv = ["--cell_1=gm", "--cell_1=gm", "--cell_2=k562", "--model_name=raw_aux_siamese", "--epochs=10", "--lr=0.001", 
           "--data_root=data/", "--save_root=Results/", "--attentionfilename=gm_k562_test_11", "--n_bins=100", 
            "--n_hms=11", "--save_attention_maps"]
exec(open("train_v1.py").read())
# Out:
# the model name:  gm_k562_raw_aux_siamese
# loading data from:   data/
# saving results in  from:  Results/gm_k562
# ==>processing data
# ==>loading train data
# Number of genes: 300
# Number of entries: 6000
# Number of HMs: 11
# Number of genes: 300
# Number of entries: 6000
# Number of HMs: 11
# ==>loading valid data
# Number of genes: 300
# Number of entries: 6000
# Number of HMs: 11
# Number of genes: 300
# Number of entries: 6000
# Number of HMs: 11
# ==>loading test data
# Number of genes: 300
# Number of entries: 6000
# Number of HMs: 11
# Number of genes: 300
# Number of entries: 6000
# Number of HMs: 11
# ==>building model
# raw_aux_siamese(
#   (rnn_hms): ModuleList(
#     (0): recurrent_encoder(
#       (rnn): LSTM(1, 32, dropout=0.5, bidirectional=True)
#       (bin_attention): rec_attention(
#         (softmax): Softmax()
#       )
#     )
#     (1): recurrent_encoder(
#       (rnn): LSTM(1, 32, dropout=0.5, bidirectional=True)
#       (bin_attention): rec_attention(
# ...
