# %%
import os
from google.colab import drive
import sys

# %%
### ONLY IF USING GOOGLE COLAB 
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
print(os.getcwd())
os.chdir("/content/drive/My Drive/COMS4995_FinalProject")
os.getcwd()
# Out:
# /content
# '/content/drive/My Drive/COMS4995_FinalProject'

# %%
# !ls
# Out:
# adapting_versions  evaluate.py	      models_v1.pyc   SiameseLoss.pyc
# data		   evaluate.pyc       __pycache__     start_test.ipynb
# data_v1.ipynb	   evaluate_v1.ipynb  README.md       test_from_train_v2.ipynb
# data_v1.py	   models_v1.ipynb    Results	      train_v2.ipynb
# data_v1.pyc	   models_v1.py       SiameseLoss.py  train_v2.py

# %%
import sys
sys.argv = ["--cell_1=gm", # placeholder i think because -h messes it up
            "--cell_1=gm", 
            "--cell_2=k562", 
            "--model_name=aux_siamese", 
            "--epochs=10", 
            "--lr=0.001", 
            "--data_root=data/", 
            "--save_root=Results/", 
            "--attentionfilename=gm_k562_test2_11.csv", 
            "--n_bins=100", 
            "--n_hms=11", 
            "--save_attention_maps"]
exec(open("train_v2.py").read())
# Out:
# the model name:  gm_k562_aux_siamese
# loading data from:   data/
# saving results in  from:  Results/gm_k562
# ==>processing data
# ==>loading train data
# Number of genes: 60
# Number of entries: 6000
# Number of HMs: 11
# Number of genes: 60
# Number of entries: 6000
# Number of HMs: 11
# ==>loading valid data
# Number of genes: 10
# Number of entries: 1000
# Number of HMs: 11
# Number of genes: 10
# Number of entries: 1000
# Number of HMs: 11
# ==>loading test data
# Number of genes: 30
# Number of entries: 3000
# Number of HMs: 11
# Number of genes: 30
# Number of entries: 3000
# Number of HMs: 11
# ==>building model
# No GPU Available
# ==>initializing a new model
# =---------------------------------------- Training 1 -----------------------------------=
# TRAINING ON BATCH: 0
# TESTING ON BATCH: 0
# Epoch: 0
# train R2: -0.18959706582992977
# valid R2: 0.24944854844060438
# best valid R2: 0.24944854844060438
# ...
