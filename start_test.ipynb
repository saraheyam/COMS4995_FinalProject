# %%
import os
from google.colab import drive
import sys

# %%
### ONLY IF USING GOOGLE COLAB 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(os.getcwd())
os.chdir("/content/drive/My Drive/COMS4995_FinalProject")
os.getcwd()
# Out:
# /content
# '/content/drive/My Drive/COMS4995_FinalProject'

# %%
# !ls
# Out:
# adapting_versions  evaluate.py	      README.md			train.py
# data		   evaluate.pyc       Results			train_v2.ipynb
# data.py		   evaluate_v1.ipynb  SiameseLoss.py		train_v2.py
# data_v1.ipynb	   models.py	      SiameseLoss.pyc
# data_v1.py	   models.pyc	      start_test.ipynb
# data_v1.pyc	   __pycache__	      test_from_train_v2.ipynb

# %%
import sys
sys.argv = ["--cell_1=E116", # placeholder i think because -h messes it up
            "--cell_1=E116", 
            "--cell_2=E123", 
            "--model_name=aux_siamese", 
            "--epochs=10", 
            "--lr=0.001", 
            "--data_root=data/", 
            "--save_root=Results/", 
            "--attentionfilename=E116_E123_train_orig.csv", 
            "--n_bins=100", 
            "--save_attention_maps"]
exec(open("train.py").read())
# Out:
# the model name:  E116_E123_aux_siamese
# loading data from:   data/
# saving results in  from:  Results/E116_E123
# ==>processing data
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-466e93cb9c89> in <module>()
#      11             "--n_bins=100",
#      12             "--save_attention_maps"]
# ---> 13 exec(open("train.py").read())
#
# <string> in <module>()
#
# AttributeError: module 'data' has no attribute 'load_data'
